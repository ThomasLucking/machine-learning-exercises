# %%
# I decided to use the already cleaned dataset for the titanic csv follow this page
# https://www.kaggle.com/datasets/jamesleslie/titanic-cleaned-data/data

# La method utiliser c'était le data imputation
"""
Imputation des données
- Age : cette colonne a été imputée en utilisant l'âge médian correspondant au titre du passager (Mr, Mrs, Dr, etc.).
  c'était imputée par titre car l'âge varie beaucoup selon Mr, Mrs, Miss ou Master. comme par exemple Dr -> Adult.
- Fare : la seule valeur manquante de cette colonne a été imputée en utilisant la valeur médiane pour la classe de ce passager.

  c'était imputée par classe car le prix du billet dépend fortement de la classe.
  
- Embarked : les deux valeurs manquantes ici ont été imputées en utilisant la méthode backfill de Pandas.
  c'était imputée par backfill car il n'y avait que 2 valeurs manquantes, donc peu d'impact.
  
  
  ya aussi une nouvelle column qui s'appelle "family_size" qui était ajouter.
  
  Pour l'entrainement j'ai décider de faire predigé qui survivé
  
  
  claude il me dise de aller dans cette direction
  
  A rough order to work through them:

1. train_test_split first — split before you fit anything.
2. LogisticRegression — your baseline model, simplest to reason about.
3. Decision Trees guide → then RandomForestClassifier — compare against the baseline, check feature_importances_.
4. Model evaluation — once you have predictions, this covers accuracy/precision/recall/F1/confusion matrices.
5. K-Means — optional, if you want to try the unsupervised clustering angle.
  
"""

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
# read the data so it is the correct dataframe.
df = pd.read_csv('titanic_clean.csv')

# we define Y as the main goal so survived
Y = df['Surived']
# x for everything else
X = df.drop(columns=['Survived'])

# then we split the data into 80% for training and 20% for tests
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.2, train_size=0.8
)
# Out:
#       Age Cabin Embarked      Fare  \
# 0    34.5   NaN        Q    7.8292
# 1    47.0   NaN        S    7.0000
# 2    62.0   NaN        Q    9.6875
# 3    27.0   NaN        S    8.6625
# 4    22.0   NaN        S   12.2875
# ..    ...   ...      ...       ...
# 413  30.0   NaN        S    8.0500
# 414  39.0  C105        C  108.9000
# 415  38.5   NaN        S    7.2500
# 416  30.0   NaN        S    8.0500
# 417   4.0   NaN        C   22.3583
#
#                                              Name  Parch  PassengerId  Pclass  \
# 0                                Kelly, Mr. James      0          892       3
# 1                Wilkes, Mrs. James (Ellen Needs)      0          893       3
# 2                       Myles, Mr. Thomas Francis      0          894       2
# 3                                Wirz, Mr. Albert      0          895       3
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)      1          896       3
# ...

# %%
## TRAINING THE MODEL WITH THE DATA USING LOGISTIC REGRESION 

"""
logistics regression predicts a category instead of linear regression which
predicts a numerical value
"""
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
# read the data so it is the correct dataframe.
df = pd.read_csv('data/titanic_cleaned.csv')

# we define Y as the main goal so survived
Y = df['Survived']
# x for everything else
X = df.drop(columns=['Survived'])
print(X.dtypes)

# then we split the data into 80% for training and 20% for tests
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.2, train_size=0.8
)

clf = LogisticRegression(random_state=0).fit(X, Y)
clf.predict(X_test[:5]) # this predicts survival if it's 0 or 1 on the first 5
clf.score(X_test, y_test)

"""
this is where the first problem arose, basically the data I found was not clean, there were cells that contained NaN which gave me errors.
so instead to make things simpler and not waste more time. claude basically wrote me a python script using pandas to well clean the data inside
of clean_data.py, which correctly outputted me the data 

https://claude.ai/share/e7e6dadf-4a5c-4f2b-84ad-364c849d58ff

"""
# Out:
# Pclass          int64
# Sex             int64
# Age           float64
# SibSp           int64
# Parch           int64
# Fare          float64
# HasCabin        int64
# FamilySize      int64
# IsAlone         int64
# Embarked_Q       bool
# Embarked_S       bool
# Title_Miss       bool
# Title_Mr         bool
# Title_Mrs        bool
# Title_Rare       bool
# dtype: object
# /opt/anaconda3/lib/python3.14/site-packages/sklearn/linear_model/_logistic.py:599: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ...

# %%
"""
then I enountered another error.

/opt/anaconda3/lib/python3.14/site-packages/sklearn/linear_model/_logistic.py:599: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT

Increase the number of iterations to improve the convergence (max_iter=100).
You might also want to scale the data as shown in:
    https://scikit-learn.org/stable/modules/preprocessing.html
Please also refer to the documentation for alternative solver options:
    https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
  n_iter_i = _check_optimize_result(

to fix this I increased the iterations number to 1000
"""

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
# read the data so it is the correct dataframe.
df = pd.read_csv('data/titanic_cleaned.csv')

# we define Y as the main goal so survived
Y = df['Survived']
# x for everything else
X = df.drop(columns=['Survived'])
print(X.dtypes)

# then we split the data into 80% for training and 20% for tests
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.2, train_size=0.8
)

clf = LogisticRegression(random_state=0, max_iter=1000).fit(X, Y) # updated the max amount of iterations.
clf.predict(X_test) # this predicts survival if it's 0 or 1 on the first 5
clf.score(X_test, y_test)

"""
The model achieved 83% accuracy it correctly classified 83% of test-set passengers as either 'survived' or 'did not survive'.
the output was 0.83
"""
# Out:
# Pclass          int64
# Sex             int64
# Age           float64
# SibSp           int64
# Parch           int64
# Fare          float64
# HasCabin        int64
# FamilySize      int64
# IsAlone         int64
# Embarked_Q       bool
# Embarked_S       bool
# Title_Miss       bool
# Title_Mr         bool
# Title_Mrs        bool
# Title_Rare       bool
# dtype: object
# 0.8379888268156425

# %%
# DECISION TREE CLASSIFIER

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
# read the data so it is the correct dataframe.
df = pd.read_csv('data/titanic_cleaned.csv')

# we define Y as the main goal so survived
Y = df['Survived']
# x for everything else
X = df.drop(columns=['Survived'])

# then we split the data into 80% for training and 20% for tests
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.2, train_size=0.8
)

clf = DecisionTreeClassifier(random_state=0)

# cross_val_scrore is basically a way of doing clf.predict and score, multiple times to be sure of consistency across the models training sessions.
scores = cross_val_score(clf, X, Y, cv=10)
print(scores)

"""After doing this with the DecisionTreeClassifier, the scores varied a lot

exact output:

[0.75555556 0.84269663 0.66292135 0.74157303 0.83146067 0.7752809
 0.80898876 0.78651685 0.80898876 0.79775281]
 
 from an original of 0.83 this one varies by a lot.
"""
# Out:
# [0.75555556 0.84269663 0.66292135 0.74157303 0.83146067 0.7752809
#  0.80898876 0.78651685 0.80898876 0.79775281]
# 'After doing this with the DecisionTreeClassifier, the scores varied a lot\n\n[0.75555556 0.84269663 0.66292135 0.74157303 0.83146067 0.7752809\n 0.80898876 0.78651685 0.80898876 0.79775281]\n'

# %%
# so I decided to find the average based on all those tests

# this is decision_tree_classifer_numbers
Decision_tree_clasiser_numbers = [0.75555556, 0.84269663, 0.66292135, 0.74157303, 0.83146067, 0.7752809,
 0.80898876, 0.78651685, 0.80898876, 0.79775281]
averageDTC = sum(Decision_tree_clasiser_numbers) / len(Decision_tree_clasiser_numbers)
print(averageDTC)
# which gave me 0.7811735320000001, as the average score with the decisionTreeClassifier

# this is for the regression logistic open

LogisticRegression_numbers = [0.82222222, 0.84269663, 0.7752809,  0.84269663, 0.82022472, 0.78651685,
 0.83146067, 0.82022472, 0.83146067, 0.86516854]

averageLR = sum(LogisticRegression_numbers) / len(LogisticRegression_numbers)
print(averageLR)

# I decided to re use the old algorithm with the cross_val_score(clf, X, Y, cv=10)
# Out:
# 0.7811735320000001
# 0.823795255

# %%
# I decided to re use the old algorithm with the cross_val_score(clf, X, Y, cv=10)

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
# read the data so it is the correct dataframe.
df = pd.read_csv('data/titanic_cleaned.csv')

# we define Y as the main goal so survived
Y = df['Survived']
# x for everything else
X = df.drop(columns=['Survived'])

# then we split the data into 80% for training and 20% for tests
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.2, train_size=0.8
)

clf = LogisticRegression(random_state=0, max_iter=1000).fit(X, Y) # updated the max amount of iterations.
scores = cross_val_score(clf, X, Y, cv=10)

print(scores)
# Out:
# [0.82222222 0.84269663 0.7752809  0.84269663 0.82022472 0.78651685
#  0.83146067 0.82022472 0.83146067 0.86516854]

# %%
"""
In the end I decided to find out the average for both algorithms after running 10 times the score and evaluation
"""

# this is decision_tree_classifer_numbers
Decision_tree_clasiser_numbers = [0.75555556, 0.84269663, 0.66292135, 0.74157303, 0.83146067, 0.7752809,
 0.80898876, 0.78651685, 0.80898876, 0.79775281]
averageDTC = sum(Decision_tree_clasiser_numbers) / len(Decision_tree_clasiser_numbers)
print(averageDTC)
# which gave me 0.7811735320000001, as the average score with the decisionTreeClassifier

# this is for the regression logistic open
LogisticRegression_numbers = [0.82222222, 0.84269663, 0.7752809,  0.84269663, 0.82022472, 0.78651685,
 0.83146067, 0.82022472, 0.83146067, 0.86516854]

averageLR = sum(LogisticRegression_numbers) / len(LogisticRegression_numbers)
print(averageLR)
# which gave me 0.823795255, as the average score with the LogisticRegression
# Out:
# 0.7811735320000001
# 0.823795255

# %%
# CONFUSION MATRIX

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# read the data so it is the correct dataframe.
df = pd.read_csv('data/titanic_cleaned.csv')

# we define Y as the main goal so survived
Y = df['Survived']
# x for everything else
X = df.drop(columns=['Survived'])

# then we split the data into 80% for training and 20% for tests
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.2, train_size=0.8
)

dtc = DecisionTreeClassifier(random_state=0)
dtc.fit(X_train, y_train)
y_pred_dtc = dtc.predict(X_test) # .predict is basically inference where the models guesses labels, for X_test

cm_dtc = confusion_matrix(y_test, y_pred_dtc)
print("confusing for dtc:", cm_dtc)


import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
# read the data so it is the correct dataframe.
df = pd.read_csv('data/titanic_cleaned.csv')

# we define Y as the main goal so survived
Y = df['Survived']
# x for everything else
X = df.drop(columns=['Survived'])

# then we split the data into 80% for training and 20% for tests
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.2, train_size=0.8
)

Lr = LogisticRegression(random_state=0, max_iter=1000).fit(X, Y) # updated the max amount of iterations.
Lr.predict(X_test) # this predicts survival if it's 0 or 1 on the first 5
y_pred_Lr = Lr.predict(X_test) # .predict is basically inference where the models guesses labels, for X_test

cm_Lr = confusion_matrix(y_test, y_pred_Lr)
print("confusing for logistics:", cm_Lr)


"""
which outputted this

confusing for dtc: [[85 17] [28 49]]
confusing for logistics: [[95 17] [17 50]]
 
so in terms of the confusing matrix for dtc

For DTC:

TN = 85, FP = 17, FN = 28, TP = 49
Total = 179
Accuracy = (85+49)/179 ≈ 74.9%
Precision = 49/(49+17) ≈ 74.2%
Recall = 49/(49+28) ≈ 63.6%
F1 ≈ 68.5%


For Logistic:

TN = 95, FP = 17, FN = 17, TP = 50
Total = 179
Accuracy = (95+50)/179 ≈ 81.0%
Precision = 50/(50+17) ≈ 74.6%
Recall = 50/(50+17) ≈ 74.6%
F1 ≈ 74.6%


so logistic regression is better here, 


so in conclusion, for this type of work. logistic regression is better here.
"""
# Out:
# confusing for dtc: [[85 17]
#  [28 49]]
# confusing for logistics: [[95 17]
#  [17 50]]
# '\n[[93 14]\n [19 53]]\n\n[[106  12]\n [ 17  44]]\n\n\n'
